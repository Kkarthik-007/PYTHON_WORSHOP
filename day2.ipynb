# %% [markdown]
# 1.Arithmetic operators
# +,-,*,/,//,%
# /---> Always returns a float value
# //---> Always returns a int value
# a=2
# b=3
# print(a**b)
# output=8
# ///a power value is 2 and b power value is 3 so 2**3=2*2*2=8

# %%
a=10
b=20
print("a=",b)
print("b=",a)
# Out:
# a= 20
# b= 10

# %%
a=10
b=20
a=a+b #30
b=a-b#10
a=a-b#20 
print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %% [markdown]
# find the unit digit and tens digit of a number using arithetic operator
# >>>when dividing a number by 10 the reminder is a unit digit
# >>>(a//b)gives quotient a= 456,b=10
# >>(456//10)=45
# >>>(456//10)%10=5## tens digit

# %%
a=456
u=a%10
t=(a//10)%10
print("Units digit =",u)
print("tens digit =",t)
# Out:
# Units digit = 6
# tens digit = 5

# %% [markdown]
# 2.ASSIGNMENT OPERATOR
# =,+=,-=,*=,/=

# %%
a=10
a+=10
#a+=10 //a=a+10
print(a)
# Out:
# 20

# %% [markdown]
# 3.RELATIONAL OPERATORS
# ==,!=,>,<,>=,>=

# %%
a=10
b=5
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a<=b)
print(a>=b)
# Out:
# False
# True
# True
# False
# False
# True

# %% [markdown]
# ASCII VALUES
# A=65 TO Z=96
# a=97 TO z=
# 0=48,1=40.......
#
#
# 4.LOGICAL OPERATORS
# AND,,,OR,,,NOT
# AND >> returns false if one conditio is false
# OR  >>  returns true if any one condition is true
# NOT  >>  returns true if false and ture if false

# %%
a=10
b=5
print(a>b and a<b)
# Out:
# False

# %%
a=10
b=5
print(a>b and a>b)
# Out:
# True

# %%
a=10
b=5
print(a>b or a<b)
# Out:
# True

# %%
a=10
b=5
print(not(a>b))
# Out:
# False

# %%
print(ord("a")+ord("b"))
# Out:
# 195

# %%
print(5>582 and 7>45 or 5<10)
# Out:
# True

# %%
#AND have high precedence than OR
print(5>2 and 10>3 or 1>5)
#TRUE and TRUE or FALSE
#TRUE or FALSE
#TRUE
# Out:
# True
