# %% [markdown]
# EXCEPTION HANDLING

# %%
#EXCEPTION-->abnormal condition which interrupts the flow of the program
a=4
b=0
print("start")
print(a/b)
print("end")
# Out:
# start
# 0
# end

# %%
#checked exception     unchecked exception
#opening a file        a=2,b=0
#reading a file        a/b
#exception handling-->

# %%
#try-->whichever line of code may throw  the excetion
a=4
b=0
print("start")
try:
    print(a/b)
except ZeroDivisionError:
    print("exception caught")
print("end")
# Out:
# start
# exception caught
# end

# %%
#balance,withdraw
#withdraw > balance-->raise("insufficient balance")
#or print("amount dispensed")
